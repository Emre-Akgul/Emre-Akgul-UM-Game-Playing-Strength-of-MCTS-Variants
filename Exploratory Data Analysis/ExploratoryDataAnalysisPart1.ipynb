# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read Training Dataset

# %%
train = pd.read_csv('../Data/train.csv', index_col='Id')
train.head()
# Out:
#                                           GameRulesetName  \
# Id
# 182695                                             Satoel
# 69996                                   Greater_Even_Loss
# 216882  Tsoro_Reentered_CapturesTsoro_Reentered_Captur...
# 196506                                              Snort
# 56937                                            Fanorona
#
#                                              agent1  \
# Id
# 182695       MCTS-UCB1Tuned-1.41421356237-MAST-true
# 69996             MCTS-UCB1GRAVE-0.1-Random200-true
# 216882  MCTS-ProgressiveHistory-0.6-Random200-false
# 196506                 MCTS-UCB1-0.6-Random200-true
# 56937       MCTS-UCB1GRAVE-1.41421356237-MAST-false
#
#                                                    agent2  Properties  Format  \
# Id
# 182695             MCTS-ProgressiveHistory-0.6-MAST-false           1       1
# 69996   MCTS-ProgressiveHistory-1.41421356237-Random20...           1       1
# ...
